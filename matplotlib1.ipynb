# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datasets\iris.csv')
df.sample(5)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\faisa\AppData\Local\Temp\ipykernel_7960\3895821705.py:1: SyntaxWarning: invalid escape sequence '\i'
#   df = pd.read_csv('datasets\iris.csv')
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 10    11            5.4           3.7            1.5           0.2
# 123  124            6.3           2.7            4.9           1.8
# 91    92            6.1           3.0            4.6           1.4
# 131  132            7.9           3.8            6.4           2.0
# 44    45            5.1           3.8            1.9           0.4
#
#              Species
# 10       Iris-setosa
# 123   Iris-virginica
# 91   Iris-versicolor
# 131   Iris-virginica
# 44       Iris-setosa

# %%
df['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2},inplace=True)
# Out:
# C:\Users\faisa\AppData\Local\Temp\ipykernel_7960\573488246.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2},inplace=True)

# %%
plt.scatter(df['SepalLengthCm'],df['PetalLengthCm'],c=df['Species'],cmap='jet')#other options for cmap are summr, winter, jet and many more

# %%
plt.figure(figsize=(25,7))

plt.scatter(df['SepalLengthCm'],df['PetalLengthCm'],c=df['Species'],cmap='winter',alpha=0.5) #alpha is opacity
plt.colorbar()

# %% [markdown]
# <h1>Annotations

# %%
#adding text to graph points
age=[10,20,30,40]
weight=[30,54,89,77]

# %%
plt.scatter(age,weight)
plt.text(10,30,'Point1',fontdict={'size':30,'color':'red'})
plt.text(20,54,'Point2',fontdict={'size':30,'color':'red'})
plt.text(30,89,'Point3',fontdict={'size':30,'color':'red'})
plt.text(40,77,'Point4',fontdict={'size':30,'color':'red'})
# Out:
# Text(40, 77, 'Point4')

# %%
df = pd.read_csv(r'datasets\batter.csv')
df = df.head(100).sample(25,random_state=42)
df
# Out:
#            batter  runs        avg  strike_rate
# 83   MC Henriques  1000  27.777778   124.843945
# 53      MK Tiwary  1695  28.728814   113.834788
# 70       DJ Hooda  1237  20.278689   127.525773
# 45     AD Russell  2039  29.985294   168.234323
# 44   AC Gilchrist  2069  27.223684   133.054662
# 39     GJ Maxwell  2320  25.494505   147.676639
# 22       PA Patel  2848  22.603175   116.625717
# 80      SP Narine  1025  14.855072   154.367470
# 10      G Gambhir  4217  31.007353   119.665153
# 0         V Kohli  6634  36.251366   125.977972
# 18   F du Plessis  3403  34.373737   127.167414
# 30      RA Jadeja  2502  26.617021   122.108346
# 73     TM Dilshan  1153  26.813953   110.124164
# 33      DA Miller  2455  36.102941   133.569097
# 90         MM Ali   910  23.333333   139.570552
# 4        SK Raina  5536  32.374269   132.535312
# 76      ML Hayden  1107  35.709677   131.942789
# 77    LMP Simmons  1079  39.962963   122.892938
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
plt.figure(figsize=(25,10))
plt.scatter(df['avg'],df['strike_rate'],s=df['runs'])
plt.xlabel('average')
plt.ylabel('strike rate')

for i in range(df.shape[0]):
    if(df['batter'].iloc[i]=='V Kohli'):
        plt.text(df['avg'].iloc[i],df['strike_rate'].iloc[i],df['batter'].iloc[i],fontdict={'size':15,'color':'brown'})
    else:

        plt.text(df['avg'].iloc[i],df['strike_rate'].iloc[i],df['batter'].iloc[i],fontdict={'size':15,'color':'green'})

plt.show()

# %% [markdown]
# Horizontal and vertical lines on graph

# %%
plt.figure(figsize=(25,10))
plt.scatter(df['avg'],df['strike_rate'],s=df['runs'],c=df['runs'],cmap='summer')
plt.legend()

for i in range(df.shape[0]):
    plt.text(df['avg'].iloc[i],df['strike_rate'].iloc[i],df['batter'].iloc[i],fontdict={'color':'red'})

plt.axhline(140,color='blue')#horizontal line
plt.axvline(35,color='green')
plt.axvline(30,color='orange')#vertical line
plt.colorbar()
plt.grid()
plt.show()
# Out:
# C:\Users\faisa\AppData\Local\Temp\ipykernel_7960\3714287748.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# SUBPLOTS

# %%
fig,ax= plt.subplots(nrows=2,ncols = 1,figsize=(15,10))#sharex parameter for same x axis 


ax[0].scatter(df['avg'],df['strike_rate'],color='red',marker='D',s=5)
ax[0].set_title('Avg vs SR')
ax[0].set_ylim(140,170)#all functions work the same, just requires the set_ in the front
ax[0].set_ylabel('SR')


ax[1].hist(df['runs'],bins=[0,1000,2000,3000,10000])
ax[1].set_title('Runs')
ax[1].set_ylabel('Occurences')
# Out:
# Text(0, 0.5, 'Occurences')

# %% [markdown]
# 2D subplots

# %%
fig,ax = plt.subplots(nrows=2,ncols=2)

# ax[0].hist(df['runs']) shows error because its a 2D array of axes
ax[0][0].hist(df['runs'])
ax[0][1].hist(df['runs'])
ax[1][0].hist(df['runs'])
ax[1][1].hist(df['runs'])
# Out:
# (array([9., 3., 6., 2., 1., 2., 0., 0., 1., 1.]),
#  array([ 910. , 1482.4, 2054.8, 2627.2, 3199.6, 3772. , 4344.4, 4916.8,
#         5489.2, 6061.6, 6634. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 2nd method of making subplots

# %%
fig =plt.figure(figsize=(25,17))#create figure object and then keep adding subplot while adjusting the rows and columns

ax1 = fig.add_subplot(2,3,1) # first two numbers is rows and columns and the third number represents the figure
ax1.hist(df['runs'])

ax2 = fig.add_subplot(2,3,2)
ax2.pie(df['runs'],autopct='%0.1f%%',labels=df['batter'])

ax3= fig.add_subplot(2,3,3)
ax3.bar(df['batter'],df['avg'])
ax3.set_ylabel('average')
ax3.set_xticks(np.arange(df.shape[0]),df['batter'],rotation=90)
ax3.axhline(30,color='red')

ax4=fig.add_subplot(2,3,4)
ax4.pie(df['runs'])

fig.show()
# Out:
# C:\Users\faisa\AppData\Local\Temp\ipykernel_7960\3722024663.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# <h1>3D PLOTS
