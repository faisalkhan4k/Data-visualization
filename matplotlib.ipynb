# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
price = [40000,50000,78000,110000]
years= [2005,2010,2016,2024]

plt.plot(years,price)

# %%
df = pd.read_csv('datasets\sharma-kohli.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\faisa\AppData\Local\Temp\ipykernel_4640\2112908173.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('datasets\sharma-kohli.csv')

# %%
df.head()
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364

# %%
plt.plot(df['index'],df['V Kohli'],color='green')
plt.plot(df['index'],df['RG Sharma'],color='red')

plt.title('Rohit vs Kohli')
plt.xlabel('years')
plt.ylabel('runs')
# Out:
# Text(0, 0.5, 'runs')
